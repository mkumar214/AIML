# %%
#libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from PIL import Image

# %%
data = pd.read_csv('Melbourne_housing_FULL.csv')

# %%
data=data['Distance']

# %%
len(data)
# Out:
# 34857

# %%
#Check data have any missing value
data.isnull().sum()
# Out:
# 1

# %%
#drop missing value
data = data.dropna()

# %%
#create a histogram which having interval 50
plt.hist(data,bins=100)
# Out:
# (array([7.700e+01, 2.900e+01, 8.300e+01, 5.230e+02, 5.750e+02, 7.640e+02,
#         5.560e+02, 8.980e+02, 5.850e+02, 9.340e+02, 9.510e+02, 1.197e+03,
#         1.044e+03, 1.320e+03, 7.870e+02, 9.030e+02, 1.709e+03, 1.125e+03,
#         9.880e+02, 1.002e+03, 9.230e+02, 1.480e+03, 6.410e+02, 2.112e+03,
#         9.420e+02, 8.970e+02, 5.010e+02, 8.900e+02, 1.608e+03, 8.660e+02,
#         1.064e+03, 2.620e+02, 4.510e+02, 5.170e+02, 4.650e+02, 3.600e+02,
#         1.470e+02, 6.180e+02, 2.680e+02, 1.020e+02, 1.710e+02, 2.440e+02,
#         5.530e+02, 7.200e+01, 3.440e+02, 3.100e+01, 8.600e+01, 2.720e+02,
#         1.350e+02, 1.900e+01, 0.000e+00, 2.540e+02, 4.400e+01, 1.950e+02,
#         2.400e+01, 6.200e+01, 2.070e+02, 1.000e+01, 0.000e+00, 5.600e+01,
#         2.000e+00, 7.000e+01, 7.000e+00, 4.000e+00, 3.700e+01, 2.560e+02,
#         0.000e+00, 1.100e+01, 1.000e+00, 7.000e+00, 2.900e+01, 2.000e+00,
#         6.200e+01, 9.800e+01, 0.000e+00, 0.000e+00, 2.000e+01, 7.000e+00,
# ...

# %%
sns.distplot(data)

# %%
data1 = pd.read_csv('Melbourne_housing_FULL.csv')

# %%
data1.dropna()
# Out:
#                  Suburb              Address  Rooms Type Method  \
# 1          Airport West        154 Halsey Rd      3    t     PI
# 2           Albert Park       105 Kerferd Rd      2    h      S
# 5            Alphington           6 Smith St      4    h      S
# 6            Alphington      5/6 Yarralea St      3    h      S
# 7                Altona         158 Queen St      3    h     VB
# 9          Altona North          45 Hearn St      5    h      S
# 10         Altona North           4 Knapp St      3    h      S
# 13             Armadale       8/19 Mercer Rd      2    u      S
# 16            Ashburton           61 Dent St      4    h      S
# 19              Ashwood           18 Teck St      2    h      S
# 21     Avondale Heights           8 Norma Ct      3    h      S
# 22     Avondale Heights        9 Rogerson St      3    h     SP
# 23            Balaclava         18 Linton St      4    h      S
# 25               Balwyn        166 Gordon St      2    h      S
# ...

# %%
sns.scatterplot(data1['Price'],data1['Rooms'])

# %%
data1.corr()
# Out:
#                   Rooms  Distance  Postcode   Bedroom  Bathroom       Car  \
# Rooms          1.000000  0.271511  0.085890  0.946755  0.611826  0.393878
# Distance       0.271511  1.000000  0.481566  0.269524  0.126201  0.241835
# Postcode       0.085890  0.481566  1.000000  0.089292  0.120080  0.067886
# Bedroom        0.946755  0.269524  0.089292  1.000000  0.614892  0.388491
# Bathroom       0.611826  0.126201  0.120080  0.614892  1.000000  0.307518
# Car            0.393878  0.241835  0.067886  0.388491  0.307518  1.000000
# Landsize       0.037402  0.060862  0.040664  0.037019  0.036333  0.037829
# YearBuilt     -0.012749  0.323059  0.089805 -0.002022  0.167955  0.128702
# Latitude       0.004872 -0.100417 -0.231027  0.003447 -0.059183 -0.009020
# Longtitude     0.103235  0.200946  0.362895  0.106164  0.106531  0.047213
# Propertycount -0.071677 -0.018140  0.017108 -0.053451 -0.032887 -0.009617
# Price          0.465238 -0.211384  0.044950  0.430275  0.429878  0.201803
#
# ...

# %%
sns.heatmap(data1.corr(),annot=True)

# %%
from sklearn.preprocessing import StandardScaler
#scales the data,Essentially retunrs the z-score of every attribute
std_scale=StandardScaler()
std_scale
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
data1['Bedroom'].dropna()
# Out:
# 0        2.0
# 1        3.0
# 2        2.0
# 3        2.0
# 4        3.0
# 5        3.0
# 6        3.0
# 7        3.0
# 8        3.0
# 9        5.0
# 10       3.0
# 12       2.0
# 13       2.0
# 14       3.0
# 15       3.0
# 16       4.0
# 18       3.0
# 19       2.0
# 21       3.0
# 22       3.0
# 23       3.0
# 24       3.0
# 25       2.0
# 26       4.0
# 27       2.0
# 28       3.0
# 29       3.0
# 30       4.0
# 31       2.0
# 34       2.0
#         ...
# 34819    3.0
# 34821    3.0
# 34822    2.0
# 34823    1.0
# 34824    1.0
# 34825    2.0
# 34826    3.0
# 34827    2.0
# 34828    5.0
# 34829    3.0
# 34830    2.0
# 34831    2.0
# 34832    3.0
# 34833    2.0
# 34835    3.0
# 34836    5.0
# 34837    3.0
# 34838    3.0
# 34840    8.0
# 34841    2.0
# 34845    3.0
# 34846    3.0
# 34848    2.0
# 34850    4.0
# 34851    3.0
# 34852    3.0
# 34853    4.0
# 34854    4.0
# 34855    3.0
# 34856    4.0
# Name: Bedroom, Length: 26640, dtype: float64

# %%
data1.fillna(data1.mean())
# Out:
#                  Suburb              Address  Rooms Type Method  \
# 0            Abbotsford        68 Studley St      2    h     SS
# 1          Airport West        154 Halsey Rd      3    t     PI
# 2           Albert Park       105 Kerferd Rd      2    h      S
# 3           Albert Park     85 Richardson St      2    h      S
# 4            Alphington         30 Austin St      3    h     SN
# 5            Alphington           6 Smith St      4    h      S
# 6            Alphington      5/6 Yarralea St      3    h      S
# 7                Altona         158 Queen St      3    h     VB
# 8          Altona North          1 Beuron Rd      3    h     SP
# 9          Altona North          45 Hearn St      5    h      S
# 10         Altona North           4 Knapp St      3    h      S
# 11         Altona North         103 Sixth Av      4    h      S
# 12             Armadale           24 Hume St      3    h      S
# 13             Armadale       8/19 Mercer Rd      2    u      S
# ...

# %%
data1['Bedroom_Stdscale']=std_scale.fit_transform(data1[['Bedroom']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-1fe698c76222> in <module>()
#       1
# ----> 2 data1['Bedroom_Stdscale']=std_scale.fit_transform(data1[['Bedroom']])
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     515         if y is None:
#     516             # fit method of arity 1 (unsupervised transformation)
# --> 517             return self.fit(X, **fit_params).transform(X)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     588         # Reset internal state before fitting
#     589         self._reset()
# --> 590         return self.partial_fit(X, y)
#     591
#     592     def partial_fit(self, X, y=None):
#
# ...
